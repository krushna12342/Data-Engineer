# %%
print("heloo world")

# %%
df.display()

# %%
df =[("rahul",25),("ram",27),("raj",31),("ravi",21)]
df= spark.createDataFrame(df,["name","age"])
df.describe()
df.display()

# %%
dataframe = [
    {"name" : "rahul" , "age" : 25},
    {"name": "raj" ,"age": 23 },
    {"name" :"satish" , "age" :23 }

]

# %%
from pyspark.sql.types import *
schemas =StructType([
    StructField("name",StringType(),True),
    StructField("age",IntegerType(),True)
]) 



dataframe= spark.createDataFrame(dataframe,schemas)
dataframe.display()

# %%
from pyspark.sql.types import *
schemas = StructType([
    StructField("Name",StringType(), True),
    StructField("Age", IntegerType(),True)

])

data = [("Alice", 30), ("Bob", 25)]
dataframe_new = spark.createDataFrame(data, schemas)
display(dataframe_new)

# %%
from pyspark.sql.types import *
schemas = StructType([
    StructField("Name",StringType(), True),
    StructField("Age", IntegerType(),True)

])
data= [("ashwini" , 28),("sagar", 34),("sakshi",27)]
data =spark.createDataFrame(data,schemas)
display(data)

# %%
df = [{"name": "Alice", "age": 30}, 
      {"name": "Bob", "age": 25},
      {"name": "Charlie", "age": 35},
      {"name": "David", "age": 40},
      {"name": "Eve", "age": 28},
      {"name": "Frank", "age": 32},
      {"name": "Grace", "age": 27},
      {"name": "Hannah", "age": 31},
      {"name": "Ivan", "age": 29},
      {"name": "Judy", "age": 33},
      {"name": "Kevin", "age": 36},
      {"name": "Liam", "age": 26},
      {"name": "Mia", "age": 34},
      {"name": "Nina", "age": 24},
      {"name": "Oliver", "age": 38},
      {"name": "Pete", "age": 22},
      {"name": "Quinn", "age": 39},
      {"name": "Ravi", "age": 21},
      {"name": "Sara", "age": 37},
      {"name": "Tom", "age": 23}
]

from pyspark.sql.types import *
schemas = StructType([
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True)
])
df = spark.createDataFrame(df, schemas)
display(df)

# %%
df_new = [{"name": "Alice", "age": 30}, 
      {"name": "Bob", "age": 25},
      {"name": "Charlie", "age": 35},
      {"name": "David", "age": 40},
      {"name": "Eve", "age": 28},
      {"name": "Frank", "age": 32},
      {"name": "Grace", "age": 27},
      {"name": "Hannah", "age": 31},
      {"name": "Ivan", "age": 29},
      {"name": "Judy", "age": 33},
      {"name": "Kevin", "age": 36},
      {"name": "Liam", "age": 26},
      {"name": "Mia", "age": 34},
      {"name": "Nina", "age": 24},
      {"name": "Oliver", "age": 38},
      {"name": "Pete", "age": 22},
      {"name": "Quinn", "age": 39},
      {"name": "Ravi", "age": 21},
      {"name": "Sara", "age": 37},
      {"name": "Tom", "age": 23}
]
from pyspark.sql.types import *
schemas = StructType([
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True)
])
df_new = spark.createDataFrame(df_new,schemas)
display(df_new)

# %%
df= [
    {"name": "Alice", "age": 30},
    {"name": "Bob", "age": 25},
    {"name": "Charlie", "age": 35},
    {"name": "David", "age": 40},
    {"name": "Eve", "age": 28},
    {"name": "Frank", "age": 32},
    {"name": "Grace", "age": 27},
    {"name": "Hannah", "age": 31},
    {"name": "Ivan", "age": 29},
    {"name": "Judy", "age": 33},
    {"name": "Kevin", "age": 36},
    {"name": "Liam", "age": 26},
    {"name": "Mia", "age": 34},
    {"name": "Nina", "age": 24},
    {"name": "Oliver", "age": 38},
    {"name": "Pete", "age": 22},
    {"name": "Quinn", "age": 39},
    {"name": "Ravi", "age": 21},
    {"name": "Sara", "age": 37},
    {"name": "Tom", "age": 23}
]
from pyspark.sql.types import * 
schemas = StructType([
    StructField("name" ,StringType(),True),
    StructField("age",IntegerType(),True)
])
df = spark.createDataFrame(df, schemas)
display(df)

# %%
data= [
    {"name": "Alice", "age": 30},
    {"name": "Bob", "age": 25},
    {"name": "Charlie", "age": 35},
    {"name": "David", "age": 40},
    {"name": "Eve", "age": 28},
    {"name": "Frank", "age": 32},
    {"name": "Grace", "age": 27},
    {"name": "Hannah", "age": 31},
    {"name": "Ivan", "age": 29},
    {"name": "Judy", "age": 33},
    {"name": "Kevin", "age": 36},
    {"name": "Liam", "age": 26},
    {"name": "Mia", "age": 34},
    {"name": "Nina", "age": 24},
    {"name": "Oliver", "age": 38},
    {"name": "Pete", "age": 22},
    {"name": "Quinn", "age": 39},
    {"name": "Ravi", "age": 21},
    {"name": "Sara", "age": 37},
    {"name": "Tom", "age": 23}
]
from pyspark.sql.types import *
schemas = StructType([
    StructField("name",StringType(),True),
    StructField("age",IntegerType(),True)
])
data= spark.createDataFrame(data,schemas)
display(data)

# %%
data = [(1,"rahul"),(2,"vikas"),(3,"nitin"),(4,"pooja"),(5,"nisha")]
from pyspark.sql.types import *

schema = StructType([
    StructField("id",IntegerType(),True),
    StructField("name",StringType(),True)
])

df = spark.createDataFrame(data,schema)
display(df)

# %%
data_new= [(1,"rahul"),(2,"vikas"),(3,"nitin"),(4,"pooja"),(5,"nisha")]


from pyspark.sql.types import *
Schema = StructType([
    StructField("id",IntegerType(),True),
    StructField ("name",StringType(),True)
])
data_df= spark.createDataFrame(data_new,Schema)
display(data_df)

# %%
    mydata= [(1,"rahul"),(2,"vikas"),(3,"nitin"),(4,"pooja"),(5,"nisha")]
    from pyspark.sql.types import *
    Schema =StructType([
        StructField ("id",IntegerType(),True),
        StructField("name",StringType(),True)
    ])

    mydata_df=spark.createDataFrame(mydata,Schema)
    mydata_df.show()

# %%
dic=[
    {"id": 1,"name":"ashwini"},
    {"id":2,"name":"sachin"},
    {"id":3,"name":"sagar"},
    {"id":4,"name":"sakshi"},
    {"id":5,"name":"sakshi"    },
    {"id":6,"name":"sakshi"},
    {"id":7,"name":"sakshi"},    
    {"id":8,"name":"sakshi"},
    {"id":9,"name":"sakshi"},
    {"id":10,"name":"sakshi"}
        
]
from pyspark.sql.types import *

Schema = StructType([
    StructField("id",IntegerType(),True),
    StructField('name',StringType(),True)])


df=spark.createDataFrame(dic,Schema)
df.display()
