# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('spark').getOrCreate()

# %%
data = [ 
 (1, "John Smith", "john.smith@gmail.com", "New York", "Python Spark"),  (2, "Alice Brown", "alice@yahoo.com", "California", "Machine Learning"),  (3, "David Miller", "david@gmail.com", "Texas", "Big Data"),  (4, "Emma Wilson", "emma@hotmail.com", "Florida", "Data Engineering"),  (5, "Robert King", "robert@gmail.com", "Chicago", "PySpark SQL") ] 
df_data=spark.createDataFrame(data,['id','name','email','city','skill'])
display(df_data)

# %%
from pyspark.sql import functions as F

# %%
from pyspark.sql.functions import *

# %% [markdown]
# ### Ascii ()

# %%
data_df=df.select(ascii(col("name"))).show()

# %% [markdown]
# ## base64()

# %%
data_df=df.select(base64(col('skill').alias("encoding"))).show()

# %% [markdown]
# ## bit length ()

# %%
data_df=df.select(bit_length(col("skill"))).show()

# %%
data_df=df.select(btrim(col("email"),)).show()

# %%
data_df=df.select(char(lit(74))).show()

# %% [markdown]
# ### char_length

# %%
data_df=df.select(char_length(col("name"))).show()

# %%
data_df=df.select(character_length(col("name"))).show()

# %%
#data_df=df.select(chr(74)).show()

# %% [markdown]
# # concat()

# %%
data_df=df.select(concat(col('name'), lit(' - '), col('city'))).show(truncate=False)

# %%
data_df=df.select(concat(col("id"),lit(" -"),col("skill"))).show(truncate=False)

# %% [markdown]
# #concat_ws()

# %%
data_df=df.select(concat_ws("-",col("name"),col("city"))).show(truncate=False)

# %%
data_df=df.select(col("name")).filter(contains(col("name"), lit('John'))).show()

# %%
from pyspark.sql.functions import *

# %%
df_demo=df_demo.select(col("name")).filter(contains(col("name"),lit("John"))).show()

# %%
df_demo.select(encode(col("name"), "UTF-8")).show()

# %%
df_demo.select(decode(col("name"), "UTF-8")).show()

# %%
df_demo.select(endswith(col("name"),lit("Alice"))).show()

# %%
df_demo.show()

# %%
df_demo.filter(col("name").endswith("r")).show()

# %%
df_demo.filter(col("name").startswith("A")).show()

# %%
df_demo.filter(col("name").startswith('E')).show()

# %%
df_demo.select(find_in_set("skill"),lit("Data Engineering")).show()

# %%
df_demo.select(upper(col("name"))).show()

# %%
df_demo.select(lower(col("name"))).show()

# %%
df_demo.select(initcap(col("name"))).show()

# %%
from pyspark.sql.functions import *

# %%
df_demo.select(length(col("name"))).show()

# %%
df_demo.select(trim(col("name"))).show()

# %%
df_demo.select(ltrim(col("name"))).show()

# %%
df_demo.select(substring_index(col("email"),"@",1)).show()

# %%
df_demo.select(substring_index(col("email"),"@",-1)).show()

# %%
df_demo.select(instr(col("email"),"@")).show()

# %%
df_demo.select("email",locate("gmail",col("email"))).show()

# %%
df_data.select(regexp_extract(col("email"),"@(.*)",1)).show()

# %%
df_data.select(regexp_replace(col("email"),"@gmail.com","@yahoo.com")).show()

# %%
df_data.select(replace(col("email"),lit(".com"),lit(".org"))).show()
