# %%
from pyspark.sql.functions import *

# %%
data= [
    (1,['python','sql','spark']),
    (2,['java','c++','scala'])
]

df=spark.createDataFrame(data,['emp_id','skils'])
df.show()

# %% [markdown]
# ### using explode to split

# %%
data_df=df.select("emp_id",explode("skils").alias("skill")).display()

# %%
data = [
    (101, "Rahul Rathod", 28, 55000, "Mumbai", "Python,SQL,PySpark", "rahul.rathod@gmail.com", "2022-01-15"),
    (102, "Sachin Patil", 30, 62000, "Pune", "Java,Spring Boot", "sachin.patil@gmail.com", "2021-06-20"),
    (103, "Amit Sharma", 35, 75000, "Delhi", "Python,Azure,ADF", "amit.sharma@gmail.com", "2020-03-10"),
    (104, "Priya Verma", 27, 58000, "Bangalore", "SQL,Power BI", "priya.verma@gmail.com", "2023-02-12"),
    (105, "Neha Singh", 29, 61000, "Hyderabad", "Python,Databricks", "neha.singh@gmail.com", "2021-11-05"),
    (106, "Rohit Gupta", 32, 70000, "Chennai", "Spark,Hadoop", "rohit.gupta@gmail.com", "2019-08-14"),
    (107, "Anjali Mehta", 26, 52000, "Ahmedabad", "SQL,ETL", "anjali.mehta@gmail.com", "2022-09-18"),
    (108, "Vikas Kumar", 34, 80000, "Noida", "AWS,Python", "vikas.kumar@gmail.com", "2018-07-25"),
    (109, "Sneha Joshi", 31, 67000, "Nagpur", "ADF,Synapse", "sneha.joshi@gmail.com", "2020-10-30"),
    (110, "Karan Malhotra", 29, 59000, "Indore", "SQL,MySQL", "karan.malhotra@gmail.com", "2021-04-08"),
    (111, "Pooja Desai", 33, 72000, "Surat", "Python,Pandas", "pooja.desai@gmail.com", "2019-12-15"),
    (112, "Arjun Reddy", 28, 56000, "Vijayawada", "Databricks,Spark", "arjun.reddy@gmail.com", "2022-06-21"),
    (113, "Deepak Yadav", 36, 85000, "Jaipur", "Azure,ADF,Synapse", "deepak.yadav@gmail.com", "2017-05-17"),
    (114, "Kavita Nair", 30, 64000, "Kochi", "SQL,Python", "kavita.nair@gmail.com", "2021-01-11"),
    (115, "Manish Tiwari", 38, 92000, "Lucknow", "Hadoop,Spark", "manish.tiwari@gmail.com", "2016-09-29"),
    (116, "Ritu Sharma", 27, 54000, "Bhopal", "Power BI,Excel", "ritu.sharma@gmail.com", "2023-03-01"),
    (117, "Nitin Jain", 31, 69000, "Chandigarh", "AWS,Databricks", "nitin.jain@gmail.com", "2020-07-07"),
    (118, "Shweta Kulkarni", 29, 61000, "Aurangabad", "Python,SQL", "shweta.kulkarni@gmail.com", "2022-04-19"),
    (119, "Akash Mishra", 35, 78000, "Kanpur", "PySpark,ADF", "akash.mishra@gmail.com", "2019-11-23"),
    (120, "Meera Iyer", 32, 73000, "Coimbatore", "Azure,Python,SQL", "meera.iyer@gmail.com", "2020-02-28")
]

columns = [
    "emp_id",
    "full_name",
    "age",
    "salary",
    "city",
    "skills",
    "email",
    "joining_date"
]

df=spark.createDataFrame(data,columns)
display(df)

# %% [markdown]
# ### Change data type using to_date

# %%
from pyspark.sql.functions import *
data_df = df.withColumn('joining_date',to_date(col("joining_date"),"yyyy-MM-dd")).display()

# %% [markdown]
# ### change datatype using cast

# %%
data_df=df.withColumn('joining_date',col("joining_date").cast("date"))

# %%
df.show(
    
)

# %%
data_df.withColumn('salary',col("salary").cast('double'))

# %% [markdown]
# ### using with column Renamed

# %%
daya_df=df.withColumnRenamed('age','Age')

# %%
data_df=df.withColumnRenamed('salary','New salary').display()

# %%
data_df=df.withColumnRenamed('full_name','Employee_Name')

# %%
data_df=df.select('emp_id',col("emp_id").cast('int').alias('Employee_id')).display()

# %%
df_new=df.select('age',col("age").cast('int').alias('Age')).display()

# %% [markdown]
# ###  using explode

# %%
data_new=df.select('emp_id',explode(split(col('skills'),','))).display()

# %% [markdown]
# ### using filter ()

# %%
data_filter=df.withColumn('skills',explode(filter(split(col('skills'),","),lambda x: x=='SQL'))).display()

# %%
from pyspark.sql.functions import *

# %%
data_filter_explode=df.withColumn('skills',explode(split(col('skills'),','))).filter(col('skills')=='SQL')

# %%
data_filter_explode.display()

# %%
data = [
    (101, "Rahul Rathod", 28, 55000, "Mumbai", "Python,SQL,PySpark", "rahul.rathod@gmail.com", "2022-01-15"),
    (102, "Sachin Patil", 30, 62000, "Pune", "Java,Spring Boot", "sachin.patil@gmail.com", "2021-06-20"),
    (103, "Amit Sharma", 35, 75000, "Delhi", "Python,Azure,ADF", "amit.sharma@gmail.com", "2020-03-10"),
    (104, "Priya Verma", 27, 58000, "Bangalore", "SQL,Power BI", "priya.verma@gmail.com", "2023-02-12"),
    (105, "Neha Singh", 29, 61000, "Hyderabad", "Python,Databricks", "neha.singh@gmail.com", "2021-11-05"),
    (106, "Rohit Gupta", 32, 70000, "Chennai", "Spark,Hadoop", "rohit.gupta@gmail.com", "2019-08-14"),
    (107, "Anjali Mehta", 26, 52000, "Ahmedabad", "SQL,ETL", "anjali.mehta@gmail.com", "2022-09-18"),
    (108, "Vikas Kumar", 34, 80000, "Noida", "AWS,Python", "vikas.kumar@gmail.com", "2018-07-25"),
    (109, "Sneha Joshi", 31, 67000, "Nagpur", "ADF,Synapse", "sneha.joshi@gmail.com", "2020-10-30"),
    (110, "Karan Malhotra", 29, 59000, "Indore", "SQL,MySQL", "karan.malhotra@gmail.com", "2021-04-08"),
    (111, "Pooja Desai", 33, 72000, "Surat", "Python,Pandas", "pooja.desai@gmail.com", "2019-12-15"),
    (112, "Arjun Reddy", 28, 56000, "Vijayawada", "Databricks,Spark", "arjun.reddy@gmail.com", "2022-06-21"),
    (113, "Deepak Yadav", 36, 85000, "Jaipur", "Azure,ADF,Synapse", "deepak.yadav@gmail.com", "2017-05-17"),
    (114, "Kavita Nair", 30, 64000, "Kochi", "SQL,Python", "kavita.nair@gmail.com", "2021-01-11"),
    (115, "Manish Tiwari", 38, 92000, "Lucknow", "Hadoop,Spark", "manish.tiwari@gmail.com", "2016-09-29"),
    (116, "Ritu Sharma", 27, 54000, "Bhopal", "Power BI,Excel", "ritu.sharma@gmail.com", "2023-03-01"),
    (117, "Nitin Jain", 31, 69000, "Chandigarh", "AWS,Databricks", "nitin.jain@gmail.com", "2020-07-07"),
    (118, "Shweta Kulkarni", 29, 61000, "Aurangabad", "Python,SQL", "shweta.kulkarni@gmail.com", "2022-04-19"),
    (119, "Akash Mishra", 35, 78000, "Kanpur", "PySpark,ADF", "akash.mishra@gmail.com", "2019-11-23"),
    (120, "Meera Iyer", 32, 73000, "Coimbatore", "Azure,Python,SQL", "meera.iyer@gmail.com", "2020-02-28")
]

columns = [
    "emp_id",
    "full_name",
    "age",
    "salary",
    "city",
    "skills",
    "email",
    "joining_date"
]

df_test=spark.createDataFrame(data,columns)
display(df)

# %%
#df_demo.withColumn('skills',explode(split(col("skills"),","))).filter(col('skills')=="Python").display()

# %%
df_test.withColumn("skills",explode(split(col("skills"),","))).filter(col("skills")=="Azure").display()

# %%
df_test.selectExpr('emp_id','cast(salary as double)as salary').show()

# %%
df_test.select("emp_id","full_name",explode(split(col("skills"),","))).display()

# %%
from pyspark.sql.functions import *

# %%
data_df=[
    (1,{'math' : 76 ,'science' : 78}),
    (2,{'math' : 80 ,'science' : 85}),
    (3,{'math' : 90 ,'science' : 95}),
    (4,{'math' : 95 ,'science' : 90}),
    (5,{'math' : 85 ,'science' : 80}),
    (6,{'math' : 70 ,'science' : 75}),
    (7,{'math' : 60 ,'science' : 65}),
    (8,{'math' : 50 ,'science' : 55}),
    (9,{'math' : 40 ,'science' : 45}),
    (10,{'math' : 30 ,'science' : 35}),
    (11,{'math' : 20 ,'science' : 25}),
    (12,{'math' : 10 ,'science' : 15}),
    (13,{'math' : 5 ,'science' : 5}),
    (14,{'math' : 0 ,'science' : 0})
]
df_ex = spark.createDataFrame(data_df,['id','mark'])
display(df_ex, truncate=False)

# %%
df_ex.select('id',explode('mark')).show()
