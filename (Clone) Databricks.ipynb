# %%
df=spark.read.json("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/employee.json")

# %%
df.display()

# %%
data= spark.read.csv("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/student_detail.csv", header=True, inferSchema=True)

# %%
data.display()

# %%
student= spark.read.json("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/student.json")

# %%
student=spark.read.json('/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/json_data/part-00004-tid-8794674680108150405-12057465-2cf1-4a08-81e6-24b01a136c26-136-1-c000.json')

# %%
student.display()

# %%
xml_df=spark.read.xml('/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/emp_info.xml')

# %%
display(xml_df)

# %%
xml_df=spark.read.format("xml").option("rowtag","employee").load("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/emp_info.xml")

# %%
xml_df.display()

# %%
parquet_df= spark.read.parquet("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/parquet_data/part-00004-tid-7831890532119188328-66d168c4-94e9-4bc4-ad78-b23e350d3e76-142-1.c000.snappy.parquet")

# %%
parquet_df.display()

# %%
emp_json=spark.read.json("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/employee_info.json")

# %%
orc_df=spark.read.orc("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/orc_data/part-00004-tid-2204942141448573224-7088434d-c74c-47c4-bf50-ed38ae8cac9f-146-1-c000.snappy.orc")

# %%
orc_df.display()

# %%
multiline_df=spark.read.option("multiline",True).csv("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/multiple_csv.csv")

# %%
multiline_df.display()

# %%
avro_df=spark.read.format("avro").load("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/avro_data/part-00004-tid-8210707561332753469-404bba67-242c-4217-989c-7e535da62fc1-152-1-c000.snappy.avro")

# %%
avro_df.display()

# %%
txt_df=spark.read.text("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/demo_text.txt")

# %%
print(txt_df)

# %%
txt_df.display()

# %%
multiline_folder=spark.read.option("multiline",True).json("/Volumes/workspace/default/my_volume/data/drive-download-20260623T025020Z-3-001/")

# %%
multiline_folder.display()
